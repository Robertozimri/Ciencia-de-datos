# %%
import numpy as np

# %%
km_anos = [44410., 5712., 37123., 0., 25757., 2003, 1991, 1990, 2020, 2006]
km_anos
# Out:
# [44410.0, 5712.0, 37123.0, 0.0, 25757.0, 2003, 1991, 1990, 2020, 2006]

# %%
info_carros=np.array(km_anos).reshape((2,5))
info_carros
# Out:
# array([[44410.,  5712., 37123.,     0., 25757.],
#        [ 2003.,  1991.,  1990.,  2020.,  2006.]])

# %%
info_carros.shape
# Out:
# (2, 5)

# %%
info_carros_copia=info_carros.copy()

# %%
info_carros_copia.resize((3,5), refcheck=False)
info_carros_copia
# Out:
# array([[44410.,  5712., 37123.,     0., 25757.],
#        [ 2003.,  1991.,  1990.,  2020.,  2006.],
#        [    0.,     0.,     0.,     0.,     0.]])

# %%
info_carros_copia[2] = info_carros_copia[0] / (2020 - info_carros_copia[1])
info_carros_copia
# Out:
# <ipython-input-13-312bee1b990d>:1: RuntimeWarning: invalid value encountered in true_divide
#   info_carros_copia[2] = info_carros_copia[0] / (2020 - info_carros_copia[1])
# array([[44410.        ,  5712.        , 37123.        ,     0.        ,
#         25757.        ],
#        [ 2003.        ,  1991.        ,  1990.        ,  2020.        ,
#          2006.        ],
#        [ 2612.35294118,   196.96551724,  1237.43333333,            nan,
#          1839.78571429]])

# %%
np.nan_to_num(info_carros_copia)
# Out:
# array([[44410.        ,  5712.        , 37123.        ,     0.        ,
#         25757.        ],
#        [ 2003.        ,  1991.        ,  1990.        ,  2020.        ,
#          2006.        ],
#        [ 2612.35294118,   196.96551724,  1237.43333333,     0.        ,
#          1839.78571429]])

# %%
# o puede ser
info_carros_copia = np.nan_to_num(np.around(info_carros_copia, 2))
info_carros_copia
# Out:
# array([[44410.  ,  5712.  , 37123.  ,     0.  , 25757.  ],
#        [ 2003.  ,  1991.  ,  1990.  ,  2020.  ,  2006.  ],
#        [ 2612.35,   196.97,  1237.43,     0.  ,  1839.79]])
