# %%
lista_km = [44410., 5712., 37123.,np.nan, 25757.]
lista_anhos = [2003, 1991, 1990, 2020, 2006]

# %%
import numpy as np

# %%
km=np.array(lista_km)
km
# Out:
# array([44410.,  5712., 37123.,     0., 25757.])

# %%
anhos=np.array(lista_anhos)
anhos
# Out:
# array([2003, 1991, 1990, 2020, 2006])

# %%
edades=2020-anhos
edades
# Out:
# array([17, 29, 30,  0, 14])

# %%
#km_total=km*edades
#km_total

# %%
km_media=km/edades
km_media
# Out:
# <ipython-input-16-218f15cec09c>:1: RuntimeWarning: invalid value encountered in true_divide
#   km_media=km/edades
# array([2612.35294118,  196.96551724, 1237.43333333,           nan,
#        1839.78571429])

# %%
np.around(km_media,2)
# Out:
# array([2612.35,  196.97, 1237.43,     nan, 1839.79])

# %%
np.nan_to_num(km_media)
# Out:
# array([2612.35294118,  196.96551724, 1237.43333333,    0.        ,
#        1839.78571429])

# %%
# o puede ser 
np.nan_to_num(np.round(km_media,2), copy=False)
# Out:
# array([2612.35,  196.97, 1237.43,    0.  , 1839.79])
