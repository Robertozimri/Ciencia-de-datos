# %%
#Potencia 
2**3
# Out:
# 8

# %%
#resto de la division 
10%3
# Out:
# 1

# %%
5*2+3*2
# Out:
# 16

# %%
5*(2+3)*2
# Out:
# 50

# %%
5*2**3
# Out:
# 40

# %%
5*2
# Out:
# 10

# %%
_+3*2
# Out:
# 16

# %%
anho_actual=2020
anho_fabircancion=2003

km_total=44410.0

# %%
anho_actual
# Out:
# 2020

# %%
print(anho_fabircancion)
print(km_total)
# Out:
# 2003
# 44410.0

# %%
km_medio=km_total/(anho_actual-anho_fabircancion)
km_medio
# Out:
# 2612.3529411764707

# %%
type(anho_actual)
type(km_total)
# Out:
# float

# %%
cero_km=True

# %%
type(cero_km)
# Out:
# bool

# %%
nombre='Jetta Variant'
nombre
# Out:
# 'Jetta Variant'

# %%
carro='''Nombre
edad
Nota'''

# %%
type(carro)
# Out:
# str

# %%
Kilometraje=None
Kilometraje

# %%
type(Kilometraje)
# Out:
# NoneType

# %%
a=10
b=20
c='Python es '
d='chevere'

# %%
a+b
# Out:
# 30

# %%
c+d
# Out:
# 'Python es chevere'

# %%
str(a)
# Out:
# '10'

# %%
type(str(a))
# Out:
# str

# %%
c+str(a)
# Out:
# 'Python es 10'

# %%
var=3.141592
int (var)
# Out:
# 3

# %%
anho_actual=2020
anho_fabricacion=2020

# %%
if(anho_actual==anho_fabricacion):
  print('verdadero')
else:
    print('Falso')
# Out:
# verdadero

# %%
#Este es un comentario
anho_actual=2020
'''este es un 
comentario'''

# %%
#Definicion de variables
anho_actual=2020
anho_fabricacion=2020

# %%
''' Estructura 
 condiconal que vamos aprender en las proximas clases
 '''
if(anho_actual==anho_fabricacion): #Probado si la condición es verdadera
  print('verdadero')
else:
    print('Falso') # Probando si la condicion es falsa

# %%
print('Hola, {}!'.format('Rodrigo'))
# Out:
# Hola, Rodrigo!

# %%
print('Hola, {}. Este es su acceso de número {}'.format('Rodrigo', 32))
# Out:
# Hola, Rodrigo. Este es su acceso de número 32

# %%
print('Hola, {nombre}. Este es su acceso de número {acceso}' .format(nombre='Rodrigo', acceso=32))
# Out:
# Hola, Rodrigo. Este es su acceso de número 32

# %%
nombre='Rodrigo'
acceso=32 
print(f'Hola, {nombre}. Este es su aceso de número {acceso}')
# Out:
# Hola, Rodrigo. Este es su aceso de número 32

# %%
input()
# Out:
# Rodrigo
# 'Rodrigo'

# %%
input('¿Cual es tu nombre?')
# Out:
# ¿Cual es tu nombre?Rodrigo
# 'Rodrigo'

# %%
anho_actual=input('Digite el año actual:')
anho_fabricacion=input('Digite el año de fabricacion: ')
km_total=input('Digite el kilometraje total: ')
km_media=int(km_total)/(int(anho_actual)- int(anho_fabricacion))
km_media
# Out:
# Digite el año actual:2020
# Digite el año de fabricacion: 2013
# Digite el kilometraje total: 51000
# 7285.714285714285

# %%
var_1=10
var_2=20
var_3='Sumado '
var_4=' con '
var_5=' tenemos '

# %%
var_3+str(var_1)+var_4+str(var_2)+var_5+ str(var_1+var_2)
# Out:
# 'Sumado 10 con 20 tenemos 30'

# %%
anho=input('Digite su edad ')
edad=2020-int(anho)
print(f'En el 2020 tienes {edad} años')
# Out:
# Digite su edad 1995
# En el 2020 tienes 25 años

# %%
peso=input('Digite su peso (kilos) ')
altura=input('Digite su altura (Metros) ')
IMC=float(peso)/ (float(altura)**2)
print(f'Su IMC es {IMC}')
# Out:
# Digite su peso (kilos) 100
# Digite su altura (Metros) 1.9
# Su IMC es 27.70083102493075
