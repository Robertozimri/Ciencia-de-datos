# %%
anho_actual=input('Digite el año actual:')
anho_fabircacion=input('Digite el año de fabricacion: ')
km_total=input('Digite el kilometraje total: ')
km_medio=int(km_total)/(int (anho_actual)-int (anho_fabircacion))
km_medio
# Out:
# Digite el año actual:2020
# Digite el año de fabricacion: 1995
# Digite el kilometraje total: 53400
# 2136.0
