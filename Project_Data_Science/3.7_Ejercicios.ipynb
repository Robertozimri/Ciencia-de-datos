# %%
dataset = {
'Dodge': {
'motor': 'Motor 6.7',
'año': 2017,
'km': 45757,
'accesorios': ['LLantas de aleación', '4 X 4', 'Central multimedia'],
'valor': 92612.1
},
'Pajero': {
'motor': 'Motor 2.4 Turbo',
'Cero_km': True,
'km': 80000,
'accesorios': ['Control de tracción', 'Bancos de cuero', 'Control de estabilidad'],
'valor': 51606.59
}
}

# %%
dataset_copia=dataset.copy()
dataset_copia
# Out:
# {'Dodge': {'motor': 'Motor 6.7',
#   'año': 2017,
#   'km': 45757,
#   'accesorios': ['LLantas de aleación', '4 X 4', 'Central multimedia'],
#   'valor': 92612.1},
#  'Pajero': {'motor': 'Motor 2.4 Turbo',
#   'Cero_km': True,
#   'km': 80000,
#   'accesorios': ['Control de tracción',
#    'Bancos de cuero',
#    'Control de estabilidad'],
#   'valor': 51606.59}}

# %%
dataset_copia['Dodge']['accesorios'].append('Airbag')

# %%
dataset_copia
# Out:
# {'Dodge': {'motor': 'Motor 6.7',
#   'año': 2017,
#   'km': 45757,
#   'accesorios': ['LLantas de aleación',
#    '4 X 4',
#    'Central multimedia',
#    'Airbag'],
#   'valor': 92612.1},
#  'Pajero': {'motor': 'Motor 2.4 Turbo',
#   'Cero_km': True,
#   'km': 80000,
#   'accesorios': ['Control de tracción',
#    'Bancos de cuero',
#    'Control de estabilidad'],
#   'valor': 51606.59}}

# %%
dataset_copia['Dodge'].get('accesorios', 'clae no encontrada ')
# Out:
# ['LLantas de aleación', '4 X 4', 'Central multimedia', 'Airbag']

# %%
dataset_copia['Dodge'].update({'año':2016})
dataset_copia
# Out:
# {'Dodge': {'motor': 'Motor 6.7',
#   'año': 2016,
#   'km': 45757,
#   'accesorios': ['LLantas de aleación',
#    '4 X 4',
#    'Central multimedia',
#    'Airbag'],
#   'valor': 92612.1,
#   'Año': 2016},
#  'Pajero': {'motor': 'Motor 2.4 Turbo',
#   'Cero_km': True,
#   'km': 80000,
#   'accesorios': ['Control de tracción',
#    'Bancos de cuero',
#    'Control de estabilidad'],
#   'valor': 51606.59}}

# %%
dataset['Dodge'].update({'año': 2016})
dataset['Pajero'].update(motor = 'Motor Diesel V8')
dataset
# Out:
# {'Dodge': {'motor': 'Motor 6.7',
#   'año': 2016,
#   'km': 45757,
#   'accesorios': ['LLantas de aleación', '4 X 4', 'Central multimedia'],
#   'valor': 92612.1},
#  'Pajero': {'motor': 'Motor Diesel V8',
#   'Cero_km': True,
#   'km': 80000,
#   'accesorios': ['Control de tracción',
#    'Bancos de cuero',
#    'Control de estabilidad'],
#   'valor': 51606.59}}
