# %%
km = np.array([44410., 5712., 37123., 0., 25757.])
anhos = np.array([2003, 1991, 1990, 2020, 2006])
datos = np.array([km, anhos])
datos
# Out:
# array([[44410.,  5712., 37123.,     0., 25757.],
#        [ 2003.,  1991.,  1990.,  2020.,  2006.]])

# %%
import numpy as np

# %%
km_anual=np.around(datos[0]/(2020-datos[1]),2)
km_anual
# Out:
# <ipython-input-6-19ffe22fc6e8>:1: RuntimeWarning: invalid value encountered in true_divide
#   km_anual=np.around(datos[0]/(2020-datos[1]),2)
# array([2612.35,  196.97, 1237.43,     nan, 1839.79])

# %%
datos[:,datos[1]>2000]
# Out:
# array([[44410.,     0., 25757.],
#        [ 2003.,  2020.,  2006.]])

# %%
km_anual<1500
# Out:
# array([False,  True,  True, False, False])

# %%
np.nan_to_num(km_anual, copy=False)
# Out:
# array([2612.35,  196.97, 1237.43,    0.  , 1839.79])

# %%
km_anual<1500
# Out:
# array([False,  True,  True,  True, False])

# %%
datos[:,km_anual<1500]
# Out:
# array([[ 5712., 37123.,     0.],
#        [ 1991.,  1990.,  2020.]])
