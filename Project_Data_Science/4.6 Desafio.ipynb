# %%
carros = ['Lamborghini', 'Versa', '207 Sedan', 'Dodge Charger', 'Aston Martin', 'Pajero TR4', 'Tiggo'
, 'Kangoo Express', 'Mohave', 'Livina', '207 SW', 'Palio Adventure', 'Tucson', 'Doblò', '500 Abarth',
'Jetta Variant', 'Range Rover Evoque', 'Up!', 'Grand Cherokee', 'HB20', 'Boxer', 'NX 200t', 'Bongo',
'RAM', 'Parati', 'Tiida Hatch', 'CR-V', 'Boxster', 'Golf', '308 CC', 'Fox', 'Z4 Roadster', 'Sandero',
'Polo Sedan', 'Veloster', 'Cadillac', 'Ford Edge', 'Discovery 4', 'EcoSport', 'Hilux', 'Logan', 'GolG4', 'Sorento', 'Santa Fe', 'Vantage Volante', 'Xsara Picasso', 'Volkswagen', 'Crossfox', 'Touareg',
'Gallardo LP 560 – 4', 'Optimmper', 'Uno', 'Ja', 'Ju3', 'Edge', 'C3 Picasso', 'Voyage', 'Cayenne', 'Passat', 'Sonata', 'Aircross', 'Linea', 'Veracruz', 'Fit', 'Idea', 'A3', 'SpaceFox', 'New Fiesta', 'DS5', 'Ford EcoSport', 'Jeep Renegade', 'Accord']

# %%
nombre_carros={}

# %%
nombres_carros = {}
for carro in carros:
  #print(primera_letra[0]) Tambien se puede 
  primera_letra=carro[0]

# %%
nombres_carros = {}
for carro in carros:
  primera_letra = carro[0]
  if(primera_letra in nombres_carros):
   nombres_carros[primera_letra].append(carro)
  else:
   nombres_carros[primera_letra] = [carro]
nombres_carros
# Out:
# {'L': ['Lamborghini', 'Livina', 'Logan', 'Linea'],
#  'V': ['Versa',
#   'Veloster',
#   'Vantage Volante',
#   'Volkswagen',
#   'Voyage',
#   'Veracruz'],
#  '2': ['207 Sedan', '207 SW'],
#  'D': ['Dodge Charger', 'Doblò', 'Discovery 4', 'DS5'],
#  'A': ['Aston Martin', 'Aircross', 'A3', 'Accord'],
#  'P': ['Pajero TR4', 'Palio Adventure', 'Parati', 'Polo Sedan', 'Passat'],
#  'T': ['Tiggo', 'Tucson', 'Tiida Hatch', 'Touareg'],
#  'K': ['Kangoo Express'],
#  'M': ['Mohave'],
#  '5': ['500 Abarth'],
#  'J': ['Jetta Variant', 'Ja', 'Ju3', 'Jeep Renegade'],
#  'R': ['Range Rover Evoque', 'RAM'],
#  'U': ['Up!', 'Uno'],
#  'G': ['Grand Cherokee', 'Golf', 'GolG4', 'Gallardo LP 560 – 4'],
#  'H': ['HB20', 'Hilux'],
#  'B': ['Boxer', 'Bongo', 'Boxster'],
#  'N': ['NX 200t', 'New Fiesta'],
#  'C': ['CR-V', 'Cadillac', 'Crossfox', 'C3 Picasso', 'Cayenne'],
#  '3': ['308 CC'],
#  'F': ['Fox', 'Ford Edge', 'Fit', 'Ford EcoSport'],
#  'Z': ['Z4 Roadster'],
# ...
