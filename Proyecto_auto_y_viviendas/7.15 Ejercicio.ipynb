# %%
import pandas as pd
import numpy as np

# %%
proyecto=pd.read_csv('https://raw.githubusercontent.com/Robertozimri/Robertozimri/main/db_proyecto.csv', sep=';')
proyecto.head()
# Out:
#            Tipo    Valor                 Barrio                Alcaldia  Area  \
# 0  Departamento   681.50  Barrio del Niño Jesús                 Tlalpan    85
# 1  Departamento   681.55                 Carola          Alvaro Obregón    60
# 2  Departamento   864.80                Condesa              Cuauhtémoc    70
# 3          Casa  1363.00              Contadero   Cuajimalpa de Morelos   131
# 4  Departamento   705.00              Del Valle           Benito Juárez    79
#
#    Recamaras  Baños  Estacionamientos  ValorMantenimiento  \
# 0          3      2               1.0                40.7
# 1          2      2               2.0                 0.0
# 2          2      2               1.0                84.6
# 3          3      2               2.0                 0.0
# 4          2      2               1.0                61.1
#
#                                      Caracteristicas
# 0  [Planta baja, Buena iluminación, Cocina integr...
# 1  [Buena iluminación,Sala Comedor,Cocina Equipad...
# 2  [Vigilancia 24 horas, Gimnasio, Roof Garden co...
# 3  [Sala, Comedor, Cocina integral,Área de lavado...
# 4  [Recámara con vestidor y baño, Closet,Comedor ...

# %%
proyecto['ValorTotal'] = proyecto['Valor'] + proyecto['ValorMantenimiento']
proyecto.head()
# Out:
#            Tipo    Valor                 Barrio                Alcaldia  Area  \
# 0  Departamento   681.50  Barrio del Niño Jesús                 Tlalpan    85
# 1  Departamento   681.55                 Carola          Alvaro Obregón    60
# 2  Departamento   864.80                Condesa              Cuauhtémoc    70
# 3          Casa  1363.00              Contadero   Cuajimalpa de Morelos   131
# 4  Departamento   705.00              Del Valle           Benito Juárez    79
#
#    Recamaras  Baños  Estacionamientos  ValorMantenimiento  \
# 0          3      2               1.0                40.7
# 1          2      2               2.0                 0.0
# 2          2      2               1.0                84.6
# 3          3      2               2.0                 0.0
# 4          2      2               1.0                61.1
#
#                                      Caracteristicas  ValorTotal
# 0  [Planta baja, Buena iluminación, Cocina integr...      722.20
# 1  [Buena iluminación,Sala Comedor,Cocina Equipad...      681.55
# 2  [Vigilancia 24 horas, Gimnasio, Roof Garden co...      949.40
# 3  [Sala, Comedor, Cocina integral,Área de lavado...     1363.00
# 4  [Recámara con vestidor y baño, Closet,Comedor ...      766.10

# %%
proyecto['ValorM2'] = proyecto['ValorTotal'] / proyecto['Area']
proyecto.head()
# Out:
#            Tipo    Valor                 Barrio                Alcaldia  Area  \
# 0  Departamento   681.50  Barrio del Niño Jesús                 Tlalpan    85
# 1  Departamento   681.55                 Carola          Alvaro Obregón    60
# 2  Departamento   864.80                Condesa              Cuauhtémoc    70
# 3          Casa  1363.00              Contadero   Cuajimalpa de Morelos   131
# 4  Departamento   705.00              Del Valle           Benito Juárez    79
#
#    Recamaras  Baños  Estacionamientos  ValorMantenimiento  \
# 0          3      2               1.0                40.7
# 1          2      2               2.0                 0.0
# 2          2      2               1.0                84.6
# 3          3      2               2.0                 0.0
# 4          2      2               1.0                61.1
#
#                                      Caracteristicas  ValorTotal    ValorM2
# 0  [Planta baja, Buena iluminación, Cocina integr...      722.20   8.496471
# 1  [Buena iluminación,Sala Comedor,Cocina Equipad...      681.55  11.359167
# 2  [Vigilancia 24 horas, Gimnasio, Roof Garden co...      949.40  13.562857
# 3  [Sala, Comedor, Cocina integral,Área de lavado...     1363.00  10.404580
# 4  [Recámara con vestidor y baño, Closet,Comedor ...      766.10   9.697468

# %%
for index, row in proyecto.iterrows():
    proyecto.loc[index,'Vigilancia']='Vigilancia 24 horas'in row['Caracteristicas']
proyecto.head()
# Out:
#            Tipo    Valor                 Barrio                Alcaldia  Area  \
# 0  Departamento   681.50  Barrio del Niño Jesús                 Tlalpan    85
# 1  Departamento   681.55                 Carola          Alvaro Obregón    60
# 2  Departamento   864.80                Condesa              Cuauhtémoc    70
# 3          Casa  1363.00              Contadero   Cuajimalpa de Morelos   131
# 4  Departamento   705.00              Del Valle           Benito Juárez    79
#
#    Recamaras  Baños  Estacionamientos  ValorMantenimiento  \
# 0          3      2               1.0                40.7
# 1          2      2               2.0                 0.0
# 2          2      2               1.0                84.6
# 3          3      2               2.0                 0.0
# 4          2      2               1.0                61.1
#
#                                      Caracteristicas  ValorTotal    ValorM2  \
# 0  [Planta baja, Buena iluminación, Cocina integr...      722.20   8.496471
# 1  [Buena iluminación,Sala Comedor,Cocina Equipad...      681.55  11.359167
# 2  [Vigilancia 24 horas, Gimnasio, Roof Garden co...      949.40  13.562857
# 3  [Sala, Comedor, Cocina integral,Área de lavado...     1363.00  10.404580
# 4  [Recámara con vestidor y baño, Closet,Comedor ...      766.10   9.697468
#
#   Vigilancia
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False

# %%
proyecto['Gimnasio'] = proyecto['Caracteristicas'].apply(lambda x: 'Gimnasio' in x)
proyecto.head()
# Out:
#            Tipo    Valor                 Barrio                Alcaldia  Area  \
# 0  Departamento   681.50  Barrio del Niño Jesús                 Tlalpan    85
# 1  Departamento   681.55                 Carola          Alvaro Obregón    60
# 2  Departamento   864.80                Condesa              Cuauhtémoc    70
# 3          Casa  1363.00              Contadero   Cuajimalpa de Morelos   131
# 4  Departamento   705.00              Del Valle           Benito Juárez    79
#
#    Recamaras  Baños  Estacionamientos  ValorMantenimiento  \
# 0          3      2               1.0                40.7
# 1          2      2               2.0                 0.0
# 2          2      2               1.0                84.6
# 3          3      2               2.0                 0.0
# 4          2      2               1.0                61.1
#
#                                      Caracteristicas  ValorTotal    ValorM2  \
# 0  [Planta baja, Buena iluminación, Cocina integr...      722.20   8.496471
# 1  [Buena iluminación,Sala Comedor,Cocina Equipad...      681.55  11.359167
# 2  [Vigilancia 24 horas, Gimnasio, Roof Garden co...      949.40  13.562857
# 3  [Sala, Comedor, Cocina integral,Área de lavado...     1363.00  10.404580
# 4  [Recámara con vestidor y baño, Closet,Comedor ...      766.10   9.697468
#
#   Vigilancia  Gimnasio
# 0       True     False
# 1       True     False
# 2       True      True
# 3       True      True
# 4      False     False

# %%
proyecto.hist(column='ValorTotal', grid=False, figsize=(14,7))
# Out:
# array([[<Axes: title={'center': 'ValorTotal'}>]], dtype=object)

# %%
proyecto.boxplot(column='ValorTotal', grid=False,vert=False, figsize=(14,7))
# Out:
# <Axes: >

# %%
proyecto.plot(kind='scatter', x='ValorTotal', y='Area', figsize=(14,7))
# Out:
# <Axes: xlabel='ValorTotal', ylabel='Area'>

# %%
pizza_accesibilidad = proyecto['Vigilancia'].value_counts()
pizza_accesibilidad.plot.pie(autopct='%.2f', figsize = (14, 7))
# Out:
# <Axes: ylabel='Vigilancia'>

# %%
pizza_piscina = proyecto['Gimnasio'].value_counts()
pizza_piscina.plot.pie(autopct='%.2f',figsize = (14, 7),explode=(0, 0.1),title='Tiene Gimnasio?')
# Out:
# <Axes: title={'center': 'Tiene Gimnasio?'}, ylabel='Gimnasio'>
